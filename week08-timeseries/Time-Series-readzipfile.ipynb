# %%
import pandas as pd
import datetime as dt
import zipfile

# %%
zf = zipfile.ZipFile('C:/Users/moconnor/Downloads/hly4935.zip') 
df = pd.read_csv(zf.open('hly4935.csv'),skiprows=23, low_memory=False)

# %%
df
# Out:
#                      date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0       10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1       31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2       31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3       31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4       31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# ...                   ...  ...  ...    ...   ...    ...   ...    ...    ...
# 221365  31-oct-2021 20:00    0  1.0      0   7.4      0   7.1    6.7    9.8
# 221366  31-oct-2021 21:00    0  0.2      0   7.3      0   6.7    6.0    9.3
# 221367  31-oct-2021 22:00    0  1.0      0   6.8      0   6.2    5.5    9.0
# 221368  31-oct-2021 23:00    0  0.4      0   6.7      0   6.1    5.3    8.9
# 221369  01-nov-2021 00:00    0  0.2      0   6.8      0   6.1    5.2    8.9
#
# ...

# %%
https://cli.fusio.net/cli/climate_data/webdata/hly4935.zip

# %%
zf = zipfile.ZipFile('https://cli.fusio.net/cli/climate_data/webdata/hly4935.zip') 
df = pd.read_csv(zf.open('hly4935.csv'),skiprows=23, low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da67fcb14249> in <module>
# ----> 1 zf = zipfile.ZipFile('https://cli.fusio.net/cli/climate_data/webdata/hly4935.zip')
#       2 df = pd.read_csv(zf.open('hly4935.csv'),skiprows=23, low_memory=False)
#
# NameError: name 'zipfile' is not defined
