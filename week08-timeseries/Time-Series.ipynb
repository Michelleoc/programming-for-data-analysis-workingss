# %% [markdown]
# # Time Series

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# https://data.gov.ie/dataset/todays-weather-knock-airport

# %%
df = pd.read_csv("knockairport.csv", skiprows=23, low_memory=False)

# %%
df
# Out:
#                     date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0       10/04/1996 14:00    0    0      0  11.5      0   8.1    3.9    0.0
# 1       31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0
# 2       31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0
# 3       31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0
# 4       31/07/1996 11:00    0    0      0  14.5      0  10.8    7.0    0.0
# ...                  ...  ...  ...    ...   ...    ...   ...    ...    ...
# 221365  31/10/2021 20:00    0  1.0      0   7.4      0   7.1    6.7    9.8
# 221366  31/10/2021 21:00    0  0.2      0   7.3      0   6.7    6.0    9.3
# 221367  31/10/2021 22:00    0  1.0      0   6.8      0   6.2    5.5    9.0
# 221368  31/10/2021 23:00    0  0.4      0   6.7      0   6.1    5.3    8.9
# 221369  01/11/2021 00:00    0  0.2      0   6.8      0   6.1    5.2    8.9
#
# ...

# %%
df = pd.read_csv("knockairport.csv", skiprows=23, low_memory=False, nrows=100)

# %%
df
# Out:
#                 date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0   10/04/1996 14:00    0    0      0  11.5      0   8.1    3.9    0.0     0
# 1   31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 2   31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 3   31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0     0
# 4   31/07/1996 11:00    0    0      0  14.5      0  10.8    7.0    0.0     0
# ..               ...  ...  ...    ...   ...    ...   ...    ...    ...   ...
# 95  04/08/1996 06:00    3    0      0  10.1      0  10.1   10.1   12.4   100
# 96  04/08/1996 07:00    0  0.1      0  10.1      0  10.1   10.1   12.4   100
# 97  04/08/1996 08:00    0    0      0  12.0      0  11.9   11.8   13.8    99
# 98  04/08/1996 09:00    0    0      0  14.8      0  12.9   11.3   13.4    79
# 99  04/08/1996 10:00    0    0      0  15.8      0  13.1   10.8   12.9    72
#
# ...

# %%
# pd.to_datetime(df['date'])

# %%
# using the date time as the index
df['datetime'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#                 date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  rhum  \
# 0   10/04/1996 14:00    0    0      0  11.5      0   8.1    3.9    0.0     0
# 1   31/07/1996 08:00    0    0      0  11.5      0  11.1   10.7    0.0     0
# 2   31/07/1996 09:00    0    0      0  11.6      0  10.7    9.8    0.0     0
# 3   31/07/1996 10:00    0    0      0  12.9      0  11.3    9.8    0.0     0
# 4   31/07/1996 11:00    0    0      0  14.5      0  10.8    7.0    0.0     0
# ..               ...  ...  ...    ...   ...    ...   ...    ...    ...   ...
# 95  04/08/1996 06:00    3    0      0  10.1      0  10.1   10.1   12.4   100
# 96  04/08/1996 07:00    0  0.1      0  10.1      0  10.1   10.1   12.4   100
# 97  04/08/1996 08:00    0    0      0  12.0      0  11.9   11.8   13.8    99
# 98  04/08/1996 09:00    0    0      0  14.8      0  12.9   11.3   13.4    79
# 99  04/08/1996 10:00    0    0      0  15.8      0  13.1   10.8   12.9    72
#
# ...

# %% [markdown]
# ## Plot

# %%
import seaborn as sns

# %%
sns.lineplot(x="datetime", y="temp", data=df[1:])
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='temp'>
